# %% [markdown]
# <a href="https://colab.research.google.com/github/janithcyapa/Decentralized-HVAC-Control-System/blob/main/energy-plus-utility.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Usage of Energy Plus Utility**

# %% [markdown]
# ## **Installation**

# %%
# !pip install -q "energy-plus-utility @ git+https://github.com/mugalan/energy-plus-utility.git@dev"
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done

# %%
from eplus import prepare_colab_eplus
prepare_colab_eplus()  # raises on failure, otherwise silent
# TODO: Allow user to specify EPLUS_DIR when running the prepare_colab_eplus()

# %%
from eplus import EPlusUtil, EPlusSqlExplorer
import subprocess, json, pathlib, os
import pandas as pd
import json

# %% [markdown]
# ## **Initialization**

# %% [markdown]
# ### **Selection of IDF files from examples**

# %% [markdown]
# #### **Initial implementation**
# `1ZoneDataCenterCRAC_wApproachTemp.idf`
# - Single-zone data center
# - CRAC unit (Computer Room Air Conditioner)
# - Simple, stable HVAC topology
# - Real HVAC system
# - Clear air mass flow path
# - Clear supply air temperature control
#
# Or use
# `1ZoneUncontrolled.idf + ZoneHVAC:IdealLoadsAirSystem`
# - Fast, conceptual, controller-logic sandbox
# - Single thermal zone
# - Simple envelope & loads
# - Infinite heating/cooling capacity
# - Zone temperature/humidity control
#
#
# #### **Decentralized Controlling**
# `5ZoneAirCooledWithDOASAirLoop.idf`.
# - DOAS (Dedicated Outdoor Air System)
# - Separation of ventilation & conditioning
# - Multi-zone building
# - Central AHU
# - Outdoor air handling
# - Zone-level terminals
# - Mass flow modulation
# - Ventilation control logic
#
# Implementation
# - Decentralized zone controller - VAV / terminal unit control
# - Zone mass flow rate command - AirTerminal:SingleDuct:*
# - Central AHU coordinator - AirLoopHVAC
# - AHU supply air temperature - Setpoint Manager (SAT)
# - AHU humidity ratio - Humidity control on air loop
# - CO₂ coordination - Controller:MechanicalVentilation
# - Aggregate ventilation logic - Outdoor Air Controller
#
# As a Secondary / fallback try `5ZoneAirCooled.idf`
# - Multiple zones
# - Central air system
# - Coils, fans, schedules

# %%
# Specify the EnergyPlus Import
EPLUS_DIR = "/root/EnergyPlus"
OUT_DIR = "/content/eplus_out"

# Define the Simulation Model
IDF = f"{EPLUS_DIR}/ExampleFiles/5ZoneAirCooled.idf"
# IDF = f"{EPLUS_DIR}/ExampleFiles/2ZoneDataCenterHVAC_wEconomizer.idf"
# Select Weather Data
EPW = f"{EPLUS_DIR}/WeatherData/USA_CA_San.Francisco.Intl.AP.724940_TMY3.epw"

# %%
# Create utility instance and set simulation model
util = EPlusUtil(verbose=1, out_dir = OUT_DIR)
# Reset and set model
util.delete_out_dir()
util.set_model(idf = IDF, epw = EPW,outdoor_co2_ppm=400.0, per_person_m3ps_per_W=3.82e-08)
util.ensure_output_sqlite()
util.enable_runtime_logging()

# %% [markdown]
# ### **Visualisation of IDF files**

# %%
# Convert the model to .json
idf_path = pathlib.Path(IDF)
converter = os.path.join(EPLUS_DIR, "ConvertInputFormat")   # on Windows it's ConvertInputFormat.exe
subprocess.run([converter, str(idf_path)], check=True)
epjson_path = idf_path.with_suffix(".epJSON")

# %%
# @title
def list_epjson_tables(epjson: dict):
    rows = []
    for obj_type, objs in epjson.items():
        count = len(objs) if isinstance(objs, dict) else "-"
        rows.append((obj_type, count))

    print(f"{'Object Type':45} | {'# Objects'}")
    print("-" * 60)
    for r in sorted(rows):
        print(f"{r[0]:45} | {r[1]}")

def show_object_table(epjson: dict, object_type: str):
    table = epjson.get(object_type)
    if table is None:
        print(f"{object_type} not found")
        return

    print(f"{object_type}")
    print("-" * len(object_type))
    for name, fields in table.items():
        print(f"\n{name}")
        for k, v in fields.items():
            print(f"  {k:35} : {v}")
def find_mass_flow_objects(epjson: dict):
    keywords = ["air_flow", "mass_flow", "flow_rate"]
    rows = []

    for obj_type, objs in epjson.items():
        if not isinstance(objs, dict):
            continue
        for name, fields in objs.items():
            for f in fields:
                if any(k in f.lower() for k in keywords):
                    rows.append((obj_type, name, f, fields[f]))

    print(f"{'Object Type':35} | {'Name':25} | {'Field':30} | Value")
    print("-" * 110)
    for r in rows:
        print(f"{r[0]:35} | {r[1]:25} | {r[2]:30} | {r[3]}")

# %%
with open(str(epjson_path), "r", encoding="utf-8") as f:
    epjson = json.load(f)

# list_epjson_tables(epjson)
# show_object_table(epjson, "AirLoopHVAC")
find_mass_flow_objects(epjson)
# Out:
# Object Type                         | Name                      | Field                          | Value
# --------------------------------------------------------------------------------------------------------------
# AirLoopHVAC                         | VAV Sys 1                 | design_supply_air_flow_rate    | Autosize
# AirTerminal:SingleDuct:VAV:Reheat   | SPACE1-1 VAV Reheat       | constant_minimum_air_flow_fraction | 0.3
# AirTerminal:SingleDuct:VAV:Reheat   | SPACE1-1 VAV Reheat       | maximum_air_flow_rate          | Autosize
# AirTerminal:SingleDuct:VAV:Reheat   | SPACE1-1 VAV Reheat       | maximum_hot_water_or_steam_flow_rate | Autosize
# AirTerminal:SingleDuct:VAV:Reheat   | SPACE1-1 VAV Reheat       | minimum_hot_water_or_steam_flow_rate | 0.0
# AirTerminal:SingleDuct:VAV:Reheat   | SPACE1-1 VAV Reheat       | zone_minimum_air_flow_input_method | Constant
# AirTerminal:SingleDuct:VAV:Reheat   | SPACE2-1 VAV Reheat       | constant_minimum_air_flow_fraction | 0.3
# AirTerminal:SingleDuct:VAV:Reheat   | SPACE2-1 VAV Reheat       | maximum_air_flow_rate          | Autosize
# AirTerminal:SingleDuct:VAV:Reheat   | SPACE2-1 VAV Reheat       | maximum_hot_water_or_steam_flow_rate | Autosize
# AirTerminal:SingleDuct:VAV:Reheat   | SPACE2-1 VAV Reheat       | minimum_hot_water_or_steam_flow_rate | 0.0
# AirTerminal:SingleDuct:VAV:Reheat   | SPACE2-1 VAV Reheat       | zone_minimum_air_flow_input_method | Constant
# AirTerminal:SingleDuct:VAV:Reheat   | SPACE3-1 VAV Reheat       | constant_minimum_air_flow_fraction | 0.3
# AirTerminal:SingleDuct:VAV:Reheat   | SPACE3-1 VAV Reheat       | maximum_air_flow_rate          | Autosize
# AirTerminal:SingleDuct:VAV:Reheat   | SPACE3-1 VAV Reheat       | maximum_hot_water_or_steam_flow_rate | Autosize
# AirTerminal:SingleDuct:VAV:Reheat   | SPACE3-1 VAV Reheat       | minimum_hot_water_or_steam_flow_rate | 0.0
# AirTerminal:SingleDuct:VAV:Reheat   | SPACE3-1 VAV Reheat       | zone_minimum_air_flow_input_method | Constant
# AirTerminal:SingleDuct:VAV:Reheat   | SPACE4-1 VAV Reheat       | constant_minimum_air_flow_fraction | 0.3
# AirTerminal:SingleDuct:VAV:Reheat   | SPACE4-1 VAV Reheat       | maximum_air_flow_rate          | Autosize
# AirTerminal:SingleDuct:VAV:Reheat   | SPACE4-1 VAV Reheat       | maximum_hot_water_or_steam_flow_rate | Autosize
# AirTerminal:SingleDuct:VAV:Reheat   | SPACE4-1 VAV Reheat       | minimum_hot_water_or_steam_flow_rate | 0.0
# AirTerminal:SingleDuct:VAV:Reheat   | SPACE4-1 VAV Reheat       | zone_minimum_air_flow_input_method | Constant
# AirTerminal:SingleDuct:VAV:Reheat   | SPACE5-1 VAV Reheat       | constant_minimum_air_flow_fraction | 0.3
# AirTerminal:SingleDuct:VAV:Reheat   | SPACE5-1 VAV Reheat       | maximum_air_flow_rate          | Autosize
# AirTerminal:SingleDuct:VAV:Reheat   | SPACE5-1 VAV Reheat       | maximum_hot_water_or_steam_flow_rate | Autosize
# AirTerminal:SingleDuct:VAV:Reheat   | SPACE5-1 VAV Reheat       | minimum_hot_water_or_steam_flow_rate | 0.0
# AirTerminal:SingleDuct:VAV:Reheat   | SPACE5-1 VAV Reheat       | zone_minimum_air_flow_input_method | Constant
# Boiler:HotWater                     | Central Boiler            | design_water_flow_rate         | Autosize
# Chiller:Electric                    | Central Chiller           | design_chilled_water_flow_rate | Autosize
# Chiller:Electric                    | Central Chiller           | design_condenser_fluid_flow_rate | Autosize
# Coil:Cooling:Water                  | Main Cooling Coil 1       | design_air_flow_rate           | Autosize
# Coil:Cooling:Water                  | Main Cooling Coil 1       | design_water_flow_rate         | Autosize
# Coil:Cooling:Water                  | OA Cooling Coil 1         | design_air_flow_rate           | Autosize
# Coil:Cooling:Water                  | OA Cooling Coil 1         | design_water_flow_rate         | Autosize
# Coil:Heating:Water                  | Main Heating Coil 1       | maximum_water_flow_rate        | Autosize
# Coil:Heating:Water                  | OA Heating Coil 1         | maximum_water_flow_rate        | Autosize
# Coil:Heating:Water                  | SPACE1-1 Zone Coil        | maximum_water_flow_rate        | Autosize
# Coil:Heating:Water                  | SPACE2-1 Zone Coil        | maximum_water_flow_rate        | Autosize
# Coil:Heating:Water                  | SPACE3-1 Zone Coil        | maximum_water_flow_rate        | Autosize
# Coil:Heating:Water                  | SPACE4-1 Zone Coil        | maximum_water_flow_rate        | Autosize
# Coil:Heating:Water                  | SPACE5-1 Zone Coil        | maximum_water_flow_rate        | Autosize
# Controller:OutdoorAir               | OA Controller 1           | maximum_outdoor_air_flow_rate  | Autosize
# Controller:OutdoorAir               | OA Controller 1           | minimum_outdoor_air_flow_rate  | Autosize
# DesignSpecification:OutdoorAir      | SZ DSOA SPACE1-1          | outdoor_air_flow_per_person    | 0.00236
# DesignSpecification:OutdoorAir      | SZ DSOA SPACE1-1          | outdoor_air_flow_per_zone      | 0.0
# DesignSpecification:OutdoorAir      | SZ DSOA SPACE1-1          | outdoor_air_flow_per_zone_floor_area | 0.000305
# DesignSpecification:OutdoorAir      | SZ DSOA SPACE2-1          | outdoor_air_flow_per_person    | 0.00236
# DesignSpecification:OutdoorAir      | SZ DSOA SPACE2-1          | outdoor_air_flow_per_zone      | 0.0
# DesignSpecification:OutdoorAir      | SZ DSOA SPACE2-1          | outdoor_air_flow_per_zone_floor_area | 0.000305
# DesignSpecification:OutdoorAir      | SZ DSOA SPACE3-1          | outdoor_air_flow_per_person    | 0.00236
# DesignSpecification:OutdoorAir      | SZ DSOA SPACE3-1          | outdoor_air_flow_per_zone      | 0.0
# DesignSpecification:OutdoorAir      | SZ DSOA SPACE3-1          | outdoor_air_flow_per_zone_floor_area | 0.000305
# DesignSpecification:OutdoorAir      | SZ DSOA SPACE4-1          | outdoor_air_flow_per_person    | 0.00236
# DesignSpecification:OutdoorAir      | SZ DSOA SPACE4-1          | outdoor_air_flow_per_zone      | 0.0
# DesignSpecification:OutdoorAir      | SZ DSOA SPACE4-1          | outdoor_air_flow_per_zone_floor_area | 0.000305
# DesignSpecification:OutdoorAir      | SZ DSOA SPACE5-1          | outdoor_air_flow_per_person    | 0.00236
# DesignSpecification:OutdoorAir      | SZ DSOA SPACE5-1          | outdoor_air_flow_per_zone      | 0.0
# DesignSpecification:OutdoorAir      | SZ DSOA SPACE5-1          | outdoor_air_flow_per_zone_floor_area | 0.000305
# Fan:VariableVolume                  | Supply Fan 1              | fan_power_minimum_flow_rate_input_method | Fraction
# Fan:VariableVolume                  | Supply Fan 1              | maximum_flow_rate              | Autosize
# PlantLoop                           | Chilled Water Loop        | maximum_loop_flow_rate         | Autosize
# PlantLoop                           | Chilled Water Loop        | minimum_loop_flow_rate         | 0.0
# PlantLoop                           | Hot Water Loop            | maximum_loop_flow_rate         | Autosize
# PlantLoop                           | Hot Water Loop            | minimum_loop_flow_rate         | 0.0
# Pump:VariableSpeed                  | CW Circ Pump              | design_maximum_flow_rate       | Autosize
# Pump:VariableSpeed                  | CW Circ Pump              | design_minimum_flow_rate       | 0
# Pump:VariableSpeed                  | CW Circ Pump              | pump_flow_rate_schedule_name   | CoolingPumpAvailSched
# Pump:VariableSpeed                  | HW Circ Pump              | design_maximum_flow_rate       | Autosize
# Pump:VariableSpeed                  | HW Circ Pump              | design_minimum_flow_rate       | 0
# Sizing:System                       | Sizing:System 1           | central_heating_maximum_system_air_flow_ratio | 0.3
# Sizing:System                       | Sizing:System 1           | cooling_supply_air_flow_rate   | 0
# Sizing:System                       | Sizing:System 1           | cooling_supply_air_flow_rate_method | DesignDay
# Sizing:System                       | Sizing:System 1           | design_outdoor_air_flow_rate   | Autosize
# Sizing:System                       | Sizing:System 1           | heating_supply_air_flow_rate   | 0
# Sizing:System                       | Sizing:System 1           | heating_supply_air_flow_rate_method | DesignDay
# Sizing:Zone                         | Sizing:Zone 1             | cooling_design_air_flow_method | DesignDayWithLimit
# Sizing:Zone                         | Sizing:Zone 1             | heating_design_air_flow_method | DesignDay
# Sizing:Zone                         | Sizing:Zone 2             | cooling_design_air_flow_method | DesignDayWithLimit
# Sizing:Zone                         | Sizing:Zone 2             | heating_design_air_flow_method | DesignDay
# Sizing:Zone                         | Sizing:Zone 3             | cooling_design_air_flow_method | DesignDayWithLimit
# Sizing:Zone                         | Sizing:Zone 3             | heating_design_air_flow_method | DesignDay
# Sizing:Zone                         | Sizing:Zone 4             | cooling_design_air_flow_method | DesignDayWithLimit
# Sizing:Zone                         | Sizing:Zone 4             | heating_design_air_flow_method | DesignDay
# Sizing:Zone                         | Sizing:Zone 5             | cooling_design_air_flow_method | DesignDayWithLimit
# Sizing:Zone                         | Sizing:Zone 5             | heating_design_air_flow_method | DesignDay
# ZoneInfiltration:DesignFlowRate     | SPACE1-1 Infil 1          | design_flow_rate               | 0.032
# ZoneInfiltration:DesignFlowRate     | SPACE1-1 Infil 1          | design_flow_rate_calculation_method | Flow/Zone
# ZoneInfiltration:DesignFlowRate     | SPACE2-1 Infil 1          | design_flow_rate               | 0.014
# ZoneInfiltration:DesignFlowRate     | SPACE2-1 Infil 1          | design_flow_rate_calculation_method | Flow/Zone
# ZoneInfiltration:DesignFlowRate     | SPACE3-1 Infil 1          | design_flow_rate               | 0.032
# ZoneInfiltration:DesignFlowRate     | SPACE3-1 Infil 1          | design_flow_rate_calculation_method | Flow/Zone
# ZoneInfiltration:DesignFlowRate     | SPACE4-1 Infil 1          | design_flow_rate               | 0.014
# ZoneInfiltration:DesignFlowRate     | SPACE4-1 Infil 1          | design_flow_rate_calculation_method | Flow/Zone
# ZoneInfiltration:DesignFlowRate     | SPACE5-1 Infil 1          | design_flow_rate               | 0.062
# ZoneInfiltration:DesignFlowRate     | SPACE5-1 Infil 1          | design_flow_rate_calculation_method | Flow/Zone

# %% [markdown]
# ## **Simulations**

# %% [markdown]
# Dry run to create tables etc.

# %%
util.dry_run_min(include_ems_edd=False)
# Out:
# EnergyPlus Starting
# EnergyPlus, Version 25.1.0-68a4a7c774, YMD=2025.12.17 17:59
# Initializing Response Factors
# Calculating CTFs for "ROOF-1"
# Calculating CTFs for "WALL-1"
# Calculating CTFs for "FLOOR-SLAB-1"
# Calculating CTFs for "INT-WALL-1"
# Initializing Window Optical Properties
# Initializing Solar Calculations
# Allocate Solar Module Arrays
# Initializing Zone and Enclosure Report Variables
# Initializing Surface (Shading) Report Variables
# Computing Interior Solar Absorption Factors
# Determining Shadowing Combinations
# Computing Window Shade Absorption Factors
# Proceeding with Initializing Solar Calculations
# Initializing Surfaces
# Initializing Outdoor environment for Surfaces
# Setting up Surface Reporting Variables
# Initializing Temperature and Flux Histories
# Initializing Window Shading
# Computing Interior Absorption Factors
# Computing Interior Diffuse Solar Absorption Factors
# Initializing Solar Heat Gains
# Initializing Internal Heat Gains
# Initializing Interior Solar Distribution
# Initializing Interior Convection Coefficients
# Gathering Information for Predefined Reporting
# Completed Initializing Surface Heat Balance
# Calculate Outside Surface Heat Balance
# Calculate Inside Surface Heat Balance
# Calculate Air Heat Balance
# Initializing HVAC
# Warming up
# Warming up
# Warming up
# Warming up
# Warming up
# Warming up
# Performing Zone Sizing Simulation for Load Component Report
# ...for Sizing Period: #1 CHICAGO_IL_USA ANNUAL HEATING 99% DESIGN CONDITIONS DB
# Warming up
# Warming up
# Warming up
# Warming up
# Warming up
# Warming up
# Performing Zone Sizing Simulation for Load Component Report
# ...for Sizing Period: #2 CHICAGO_IL_USA ANNUAL COOLING 1% DESIGN CONDITIONS DB/MCWB
# Re-zeroing zone sizing arrays
# Warming up
# Warming up
# Warming up
# Warming up
# Warming up
# Warming up
# Performing Zone Sizing Simulation
# ...for Sizing Period: #1 CHICAGO_IL_USA ANNUAL HEATING 99% DESIGN CONDITIONS DB
# Warming up
# Warming up
# Warming up
# Warming up
# Warming up
# Warming up
# Performing Zone Sizing Simulation
# ...for Sizing Period: #2 CHICAGO_IL_USA ANNUAL COOLING 1% DESIGN CONDITIONS DB/MCWB
# Calculating System sizing
# ...for Sizing Period: #1 CHICAGO_IL_USA ANNUAL HEATING 99% DESIGN CONDITIONS DB
# Calculating System sizing
# ...for Sizing Period: #2 CHICAGO_IL_USA ANNUAL COOLING 1% DESIGN CONDITIONS DB/MCWB
# Adjusting Air System Sizing
# Adjusting Standard 62.1 Ventilation Sizing
# Initializing Simulation
# Reporting Surfaces
# Beginning Primary Simulation
# Initializing New Environment Parameters
# Warming up {1}
# Warming up {2}
# Warming up {3}
# Warming up {4}
# Warming up {5}
# Warming up {6}
# Starting Simulation at 01/21 for CHICAGO_IL_USA ANNUAL HEATING 99% DESIGN CONDITIONS DB
# Initializing New Environment Parameters
# Warming up {1}
# Warming up {2}
# Warming up {3}
# Warming up {4}
# Warming up {5}
# Warming up {6}
# Starting Simulation at 07/21 for CHICAGO_IL_USA ANNUAL COOLING 1% DESIGN CONDITIONS DB/MCWB
# Writing tabular output file results using HTML format.
# EnergyPlus Run Time=00hr 00min  0.50sec
# 0

# %%
util.list_zone_names()
# Out:
# ['PLENUM-1', 'SPACE1-1', 'SPACE2-1', 'SPACE3-1', 'SPACE4-1', 'SPACE5-1']

# %%
util.list_available_variables()
# Out:
#               Kind                                       VariableName  \
# 0   Outputvariable                          Lights Electricity Energy
# 1   Outputvariable                          Lights Electricity Energy
# 2   Outputvariable                          Lights Electricity Energy
# 3   Outputvariable                          Lights Electricity Energy
# 4   Outputvariable                          Lights Electricity Energy
# 5   Outputvariable              Electric Equipment Electricity Energy
# 6   Outputvariable              Electric Equipment Electricity Energy
# 7   Outputvariable              Electric Equipment Electricity Energy
# 8   Outputvariable              Electric Equipment Electricity Energy
# 9   Outputvariable              Electric Equipment Electricity Energy
# 10  Outputvariable            Zone Air System Sensible Heating Energy
# 11  Outputvariable            Zone Air System Sensible Cooling Energy
# 12  Outputvariable            Zone Air System Sensible Heating Energy
# 13  Outputvariable            Zone Air System Sensible Cooling Energy
# 14  Outputvariable            Zone Air System Sensible Heating Energy
# 15  Outputvariable            Zone Air System Sensible Cooling Energy
# 16  Outputvariable            Zone Air System Sensible Heating Energy
# 17  Outputvariable            Zone Air System Sensible Cooling Energy
# 18  Outputvariable            Zone Air System Sensible Heating Energy
# 19  Outputvariable            Zone Air System Sensible Cooling Energy
# 20  Outputvariable            Zone Air System Sensible Heating Energy
# 21  Outputvariable            Zone Air System Sensible Cooling Energy
# 22  Outputvariable        Facility Total Purchased Electricity Energy
# 23  Outputvariable          Facility Total Surplus Electricity Energy
# 24  Outputvariable          Facility Net Purchased Electricity Energy
# 25  Outputvariable                        Heating Coil Heating Energy
# 26  Outputvariable      Heating Coil Source Side Heat Transfer Energy
# 27  Outputvariable                        Heating Coil Heating Energy
# 28  Outputvariable      Heating Coil Source Side Heat Transfer Energy
# 29  Outputvariable                        Heating Coil Heating Energy
# 30  Outputvariable      Heating Coil Source Side Heat Transfer Energy
# 31  Outputvariable                        Heating Coil Heating Energy
# 32  Outputvariable      Heating Coil Source Side Heat Transfer Energy
# 33  Outputvariable                        Heating Coil Heating Energy
# 34  Outputvariable      Heating Coil Source Side Heat Transfer Energy
# 35  Outputvariable                        Heating Coil Heating Energy
# 36  Outputvariable      Heating Coil Source Side Heat Transfer Energy
# 37  Outputvariable                        Heating Coil Heating Energy
# 38  Outputvariable      Heating Coil Source Side Heat Transfer Energy
# 39  Outputvariable                  Cooling Coil Total Cooling Energy
# 40  Outputvariable      Cooling Coil Source Side Heat Transfer Energy
# 41  Outputvariable                  Cooling Coil Total Cooling Energy
# 42  Outputvariable      Cooling Coil Source Side Heat Transfer Energy
# 43  Outputvariable                             Fan Electricity Energy
# 44  Outputvariable                              Boiler Heating Energy
# 45  Outputvariable                           Boiler NaturalGas Energy
# 46  Outputvariable                Boiler Ancillary Electricity Energy
# 47  Outputvariable                 Boiler Ancillary NaturalGas Energy
# 48  Outputvariable                         Chiller Electricity Energy
# 49  Outputvariable                  Chiller Evaporator Cooling Energy
# 50  Outputvariable             Chiller Condenser Heat Transfer Energy
# 51  Outputvariable                            Pump Electricity Energy
# 52  Outputvariable                            Pump Electricity Energy
# 53  Outputvariable  Environmental Impact Total N2O Emissions Carbo...
# 54  Outputvariable  Environmental Impact Total CH4 Emissions Carbo...
# 55  Outputvariable  Environmental Impact Total CO2 Emissions Carbo...
#
#                KeyValue Units
# 0     SPACE1-1 LIGHTS 1     J
# 1     SPACE2-1 LIGHTS 1     J
# 2     SPACE3-1 LIGHTS 1     J
# 3     SPACE4-1 LIGHTS 1     J
# 4     SPACE5-1 LIGHTS 1     J
# 5     SPACE1-1 ELECEQ 1     J
# 6     SPACE2-1 ELECEQ 1     J
# 7     SPACE3-1 ELECEQ 1     J
# 8     SPACE4-1 ELECEQ 1     J
# 9     SPACE5-1 ELECEQ 1     J
# 10             PLENUM-1     J
# 11             PLENUM-1     J
# 12             SPACE1-1     J
# 13             SPACE1-1     J
# 14             SPACE2-1     J
# 15             SPACE2-1     J
# 16             SPACE3-1     J
# 17             SPACE3-1     J
# 18             SPACE4-1     J
# 19             SPACE4-1     J
# 20             SPACE5-1     J
# 21             SPACE5-1     J
# 22       WHOLE BUILDING     J
# 23       WHOLE BUILDING     J
# 24       WHOLE BUILDING     J
# 25   SPACE1-1 ZONE COIL     J
# 26   SPACE1-1 ZONE COIL     J
# 27   SPACE2-1 ZONE COIL     J
# 28   SPACE2-1 ZONE COIL     J
# 29   SPACE3-1 ZONE COIL     J
# 30   SPACE3-1 ZONE COIL     J
# 31   SPACE4-1 ZONE COIL     J
# 32   SPACE4-1 ZONE COIL     J
# 33   SPACE5-1 ZONE COIL     J
# 34   SPACE5-1 ZONE COIL     J
# 35    OA HEATING COIL 1     J
# 36    OA HEATING COIL 1     J
# 37  MAIN HEATING COIL 1     J
# 38  MAIN HEATING COIL 1     J
# 39    OA COOLING COIL 1     J
# 40    OA COOLING COIL 1     J
# 41  MAIN COOLING COIL 1     J
# 42  MAIN COOLING COIL 1     J
# 43         SUPPLY FAN 1     J
# 44       CENTRAL BOILER     J
# 45       CENTRAL BOILER     J
# 46       CENTRAL BOILER     J
# 47       CENTRAL BOILER     J
# 48      CENTRAL CHILLER     J
# 49      CENTRAL CHILLER     J
# 50      CENTRAL CHILLER     J
# 51         HW CIRC PUMP     J
# 52         CW CIRC PUMP     J
# 53                 SITE    kg
# 54                 SITE    kg
# 55                 SITE    kg

# %%
util.list_available_actuators()
# Out:
#           Kind            ComponentType          ControlType  \
# 0     Actuator         Schedule:Compact       Schedule Value
# 1     Actuator         Schedule:Compact       Schedule Value
# 2     Actuator         Schedule:Compact       Schedule Value
# 3     Actuator         Schedule:Compact       Schedule Value
# 4     Actuator         Schedule:Compact       Schedule Value
# ...        ...                      ...                  ...
# 1209  Actuator  Outdoor Air System Node  Drybulb Temperature
# 1210  Actuator  Outdoor Air System Node  Wetbulb Temperature
# 1211  Actuator  Outdoor Air System Node           Wind Speed
# 1212  Actuator  Outdoor Air System Node       Wind Direction
# 1213  Actuator              AirLoopHVAC  Availability Status
#
#                                ActuatorKey     Units
# 0                                 OCCUPY-1       [ ]
# 1                                 LIGHTS-1       [ ]
# 2                                  EQUIP-1       [ ]
# 3                                INFIL-SCH       [ ]
# 4                                  ACTSCHD       [ ]
# ...                                    ...       ...
# 1209  CENTRAL CHILLER CONDENSER INLET NODE       [C]
# 1210  CENTRAL CHILLER CONDENSER INLET NODE       [C]
# 1211  CENTRAL CHILLER CONDENSER INLET NODE     [m/s]
# 1212  CENTRAL CHILLER CONDENSER INLET NODE  [degree]
# 1213                             VAV SYS 1       [ ]
#
# [1214 rows x 5 columns]

# %%
util.list_available_meters()
# Out:
#             Kind                                    MeterName Units
# 0    Outputmeter                         Electricity:Facility     J
# 1    Outputmeter                         Electricity:Building     J
# 2    Outputmeter                    Electricity:Zone:SPACE1-1     J
# 3    Outputmeter                Electricity:SpaceType:GENERAL     J
# 4    Outputmeter                   InteriorLights:Electricity     J
# ..           ...                                          ...   ...
# 113  Outputmeter                   Carbon Equivalent:Facility    kg
# 114  Outputmeter  CarbonEquivalentEmissions:Carbon Equivalent    kg
# 115  Outputmeter                              MYGENERALLIGHTS     J
# 116  Outputmeter                           MYBUILDINGELECTRIC     J
# 117  Outputmeter                              MYBUILDINGOTHER     J
#
# [118 rows x 3 columns]
